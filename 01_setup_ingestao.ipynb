# %% [markdown]
# ✅ CÉLULA 1 – Bibliotecas e Configurações

# %% [markdown]
# #### 📚 BIBLIOTECAS E CONFIGURAÇÕES GERAIS
# #### Projeto: Dataflow Sentinel – MVP de Arquitetura de Dados
# #### Bloco 1: Setup Inicial e Ingestão de Dados

# %%
# 📚 BIBLIOTECAS E CONFIGURAÇÕES GERAIS
# Projeto: Dataflow Sentinel – MVP de Arquitetura de Dados
# Bloco 1: Setup Inicial e Ingestão de Dados


# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo de plots
sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (12, 6)

# Sistema e logging
import os
import logging

# Configurar logging
logging.basicConfig(level=logging.INFO,
                    format='[%(levelname)s] %(asctime)s - %(message)s',
                    datefmt='%H:%M:%S')
logger = logging.getLogger()

# %% [markdown]
# ✅ CÉLULA 2 – Caminho e Leitura do CSV

# %% [markdown]
# #### 📁 LEITURA DO ARQUIVO CSV SIMULADO

# %%
# =============================================================
# 📁 LEITURA DO ARQUIVO CSV SIMULADO
# =============================================================

# Definir o caminho do arquivo CSV carregado no Colab
csv_path = '/content/dataflow_sentinel_supplyops.csv'

# Verificar se o arquivo existe
if not os.path.exists(csv_path):
    logger.error(f"Arquivo CSV não encontrado: {csv_path}")
else:
    logger.info(f"Arquivo localizado: {csv_path}")

# Carregar os dados
df = pd.read_csv(csv_path)

# Exibir as primeiras linhas
df.head()
# Out:
#   shipment_id route_id        date  delay_minutes  cost_usd  temp_c  \
# 0    SHP10000     RT02  1998-01-08             12     36.23     7.4
# 1    SHP10001     RT03  1998-01-09              8     37.28     4.4
# 2    SHP10002     RT04  1998-01-10              7     31.80     3.1
# 3    SHP10003     RT04  1998-01-11             12     98.73     5.1
# 4    SHP10004     RT02  1998-01-12             10     69.52     0.8
#
#        status
# 0   delivered
# 1      failed
# 2  in_transit
# 3  in_transit
# 4   delivered

# %% [markdown]
# ✅ CÉLULA 3 – Preview do Dataset

# %% [markdown]
# #### 🔍 ANÁLISE INICIAL DOS DADOS

# %%
# =============================================================
# 🔍 ANÁLISE INICIAL DOS DADOS
# =============================================================

# Tamanho do dataset
logger.info(f"Total de registros: {df.shape[0]}")
logger.info(f"Total de colunas: {df.shape[1]}")

# Tipos de dados
print("📌 Tipos de dados:")
display(df.dtypes)

# Valores ausentes
print("🧼 Valores ausentes por coluna:")
display(df.isnull().sum())

# Estatísticas básicas
print("📊 Estatísticas descritivas:")
display(df.describe())
# Out:
# 📌 Tipos de dados:
# shipment_id       object
# route_id          object
# date              object
# delay_minutes      int64
# cost_usd         float64
# temp_c           float64
# status            object
# dtype: object
# 🧼 Valores ausentes por coluna:
# shipment_id      0
# route_id         0
# date             0
# delay_minutes    0
# cost_usd         0
# temp_c           0
# status           0
# dtype: int64
# 📊 Estatísticas descritivas:
#        delay_minutes      cost_usd        temp_c
# count   10000.000000  10000.000000  10000.000000
# mean       10.045900     64.896694      4.986970
# std         3.157941     20.323920      1.998786
# min         1.000000     30.010000     -2.900000
# 25%         8.000000     47.117500      3.600000
# 50%        10.000000     64.930000      5.000000
# 75%        12.000000     82.480000      6.300000
# max        24.000000    100.000000     13.400000

# %% [markdown]
# ✅ CÉLULA 4 – Análise Exploratória Rápida

# %% [markdown]
# #### 📊 ANÁLISE EXPLORATÓRIA VISUAL INICIAL

# %%
# =============================================================
# 📊 ANÁLISE EXPLORATÓRIA VISUAL INICIAL
# =============================================================

# Distribuição de status das entregas
sns.countplot(data=df, x="status")
plt.title("Distribuição de Status das Entregas")
plt.show()

# Boxplot de custos por rota
sns.boxplot(data=df, x="route_id", y="cost_usd")
plt.title("Custos por Rota")
plt.show()

# Temperatura média por status
sns.barplot(data=df, x="status", y="temp_c", estimator=np.mean)
plt.title("Temperatura Média por Status")
plt.show()
